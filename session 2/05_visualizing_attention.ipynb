# %% [markdown]
# NLP Training 5: Visualizing Attention
# ---

# %%
# %pip install bertviz
# Out:
# Requirement already satisfied: bertviz in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (4.64.0)
# Requirement already satisfied: boto3 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (1.24.64)
# Requirement already satisfied: regex in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (2022.8.17)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (2.28.1)
# Requirement already satisfied: sentencepiece in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (0.1.97)
# Requirement already satisfied: transformers>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (4.21.1)
# Requirement already satisfied: torch>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from bertviz) (1.12.1)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from torch>=1.0->bertviz) (4.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from transformers>=2.0->bertviz) (6.0)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from transformers>=2.0->bertviz) (1.23.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from transformers>=2.0->bertviz) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from transformers>=2.0->bertviz) (0.9.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from transformers>=2.0->bertviz) (0.11.4)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from transformers>=2.0->bertviz) (3.8.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.64 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from boto3->bertviz) (1.27.64)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from boto3->bertviz) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from boto3->bertviz) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from requests->bertviz) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from requests->bertviz) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from requests->bertviz) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from requests->bertviz) (2022.6.15)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from botocore<1.28.0,>=1.27.64->boto3->bertviz) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from packaging>=20.0->transformers>=2.0->bertviz) (3.0.9)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/nlp-training/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.64->boto3->bertviz) (1.16.0)

# %%
import os
os.chdir('..')
print(f'Setting working dir to: {os.getcwd()}')
# Out:
# Setting working dir to: /Users/ingomarquart/Documents/GitHub/itern-nlp-training-cases

# %% [markdown]
# ## Visualizing Attention Layers of a standard BERT model
#
# In this notebook, we will use transformers to load a pre-trained BERT Encoder model
#
# The package [bertviz](https://github.com/jessevig/bertviz) provides some interesting tools to play with for visualizing the attention mechanism discussed in the theory section.
#
# Give it a shot!

# %% [markdown]
# ### Exercise 1 - Load BERT
#
# Try to use the Transformers package to download and initialize a BERT model (`bert-base-cased`) using the `BertModel` and the `.from_pretrained()`-method. Note that we want to output attentions, so we specify it in the config (`output_attentions=True`). You also need the tokenizer, use the `BertTokenizer` to load the tokenizer.

# %%
from bertviz import *
from transformers import BertTokenizer, BertModel

model_name = 'bert-base-cased'


# Add your solution here:
# ...

# %%
# Get the model from ModelHub
model = BertModel.from_pretrained(model_name, output_attentions=True)
# We will also need the tokenizer
tokenizer = BertTokenizer.from_pretrained(model_name)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ### Exercise 2 - Encoding a Sentence
#
# We are ready to encode a sentence.
#
# Some things of note: We need to specify that we wish to receive PyTorch tensors via `return_tensors="pt"`. Transformers now works beyond just PyTorch!
#
# Second, the Tokenizer returns a dictionary that also includes attention_mask (all ones here) and token_type_ids for the next-sentence objective.
# We do not require these latter two tensors, and luckily BERT works without them. Try to extract only the input_ids.

# %%
sentence = "I play the guitar."
sentence2 = "The play is at the theater."

# Add your solution here:
# ...

# %%
# Tokenize the sentences
tokenizer_output = tokenizer(sentence, return_tensors='pt')
tokenizer_output2 = tokenizer(sentence2, return_tensors='pt')

# Get only the token ids
token_ids = tokenizer_output['input_ids']
token_ids2 = tokenizer_output2['input_ids']

# %% [markdown]
# ### Exercise 3 - Forward Pass Through the Model
#
# We are no ready to call BERT.
#
# Again, we will receive a dict-like object giving us
# - the last hidden states
# - the output of the pooler
#
# and, since we requested it
# - all attention scores across all layers
#
# Do the following:
# - Pass the tokenized sentence through the model
# - Extract the last hidden state from the output of the model
# - Report it's shape
# - How many attention layers are there?
# - What is the shape of one of the attention layers?

# %%
# Add your solution here:
# ...

# %%
BERT_output = model(token_ids)

# A hidden layer - 1 batch, 7 tokens, and 768 hidden dimensions
print(f"Size of last hidden layer: {BERT_output['last_hidden_state'].shape}")

# By contrast, a rather hefty collection of all attentions
# Note we have 12 layers
print(f"Number of layers: {len(BERT_output['attentions'])}")

# And we have provided 1 batch of 7 tokens into each of the 12 attention heads
print(f"Shape of attention vectors from one layer: {BERT_output['attentions'][2].shape}")
# Out:
# Size of last hidden layer: torch.Size([1, 7, 768])
# Number of layers: 12
# Shape of attention vectors from one layer: torch.Size([1, 12, 7, 7])

# %% [markdown]
# ### Exercise 4 - Visualizing Attention
#
# Since we have supplied one sentence with 7 words, the attention matrices will be 7 by 7.
#
# Let's visualize them using the `head_view` function from `bertviz`!

# %%
# Add your solution here:
# ...

# %%
# To convert tokens, BertTokenizer asks for a list, whereas the model requires a tensor... This was always a quirk of Transformers
head_view(BERT_output['attentions'], tokenizer.convert_ids_to_tokens(token_ids[0].tolist()))
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-a7a87cc33468434a9c9591b04e313184" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# In the default view, we can see across layers and heads.
# Scroll over "play", to see that BERT attributes much attention to "guitar"!
#
# Now do the same for the second sentence and again find out which word has much attention to "play".

# %%
# Add your solution here:
# ...

# %%
# To convert tokens, BertTokenizer asks for a list, whereas the model requires a tensor... This was always a quirk of Transformers
BERT_output2 = model(token_ids2)

head_view(BERT_output2['attentions'], tokenizer.convert_ids_to_tokens(token_ids2[0].tolist()))
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-efad0e11e1b64333b2ae76782f40131f" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# ### Exercise 5 - Visualizing the Whole Network
#
# Similarly, we can visualize the whole network using the `model_view` function of `bertviz`.

# %%
model_view(BERT_output['attentions'], tokenizer.convert_ids_to_tokens(token_ids[0].tolist()))
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-5a3d8726837f41139ae3f390acfefd1a" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#
#             </span>
#             <div id='vis'></div>
#         </div>
